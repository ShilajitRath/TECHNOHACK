# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
train=pd.read_csv(r'train.csv',index_col='PassengerId')
test=pd.read_csv(r'test.csv',index_col='PassengerId')

# %%
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Data cleaning

# %%
train.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
train.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
test.isna().sum()
# Out:
# Pclass        0
# Name          0
# Sex           0
# Age          86
# SibSp         0
# Parch         0
# Ticket        0
# Fare          1
# Cabin       327
# Embarked      0
# dtype: int64

# %%
#handling missing value in train

train.drop(columns=['Cabin'],inplace=True)
train["Age"].fillna(train["Age"].mean(), inplace=True)

#handling missing values in test
test.drop(columns=['Cabin'],inplace=True)
test["Age"].fillna(test["Age"].mean(), inplace=True)
test["Fare"].fillna(test["Fare"].mean(), inplace=True)

# %%
test.isnull().sum()
# Out:
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %%
train["Embarked"].value_counts()
train["Embarked"].fillna("S", inplace=True)

# %%
train.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# ### Summary and statistics

# %%
train.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.002015    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    418 non-null    int64
#  1   Name      418 non-null    object
#  2   Sex       418 non-null    object
#  3   Age       418 non-null    float64
#  4   SibSp     418 non-null    int64
#  5   Parch     418 non-null    int64
#  6   Ticket    418 non-null    object
#  7   Fare      418 non-null    float64
#  8   Embarked  418 non-null    object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 32.7+ KB

# %% [markdown]
# ## Univariate Analysis

# %%
train["Survived"].value_counts()
sns.countplot(x=train["Survived"],data=train)
death_percentage=round((train["Survived"].value_counts().values[0]/891)*100)
print("out of 891 {}% of people died in the accident".format(death_percentage))
# Out:
# out of 891 62% of people died in the accident

# %%
sns.countplot(x=train["Pclass"], data=train)
print((train["Pclass"].value_counts()/891)*100)
death_percentage_c3=round((train["Pclass"].value_counts().values[0]/891)*100)
print("{}% of total deaths were in Pclass 3".format(death_percentage_c3))
death_percentage_c1=round((train["Pclass"].value_counts().values[1]/891)*100)
print("{}% of total deaths were in Pclass 1".format(death_percentage_c1))
death_percentage_c2=round((train["Pclass"].value_counts().values[2]/891)*100)
print(" {}% of of total deaths were in Pclass 2".format(death_percentage_c2))
# Out:
# 3    55.106622
# 1    24.242424
# 2    20.650954
# Name: Pclass, dtype: float64
# 55% of total deaths were in Pclass 3
# 24% of total deaths were in Pclass 1
#  21% of of total deaths were in Pclass 2

# %%
sns.countplot(x=train["Sex"], data=train)
print((train["Sex"].value_counts()/891)*100)
death_percentage_male=round((train["Sex"].value_counts().values[0]/891)*100)
print(" {}% were male who died in the accident ".format(death_percentage_male))
death_percentage_female=round((train["Sex"].value_counts().values[1]/891)*100)
print(" {}% were female who died in the accident ".format(death_percentage_female))
# Out:
# male      64.758698
# female    35.241302
# Name: Sex, dtype: float64
#  65% were male who died in the accident
#  35% were female who died in the accident

# %%
sns.countplot(x=train["SibSp"] , data=train)
print((train["SibSp"].value_counts()/891)*100)
# Out:
# 0    68.237935
# 1    23.456790
# 2     3.142536
# 4     2.020202
# 3     1.795735
# 8     0.785634
# 5     0.561167
# Name: SibSp, dtype: float64

# %%
sns.countplot(x=train["Parch"] , data=train)
print((train["Parch"].value_counts()/891)*100)
# Out:
# 0    76.094276
# 1    13.243547
# 2     8.978676
# 5     0.561167
# 3     0.561167
# 4     0.448934
# 6     0.112233
# Name: Parch, dtype: float64

# %%
sns.countplot(x=train["Embarked"] , data=train)
print((train["Embarked"].value_counts()/891)*100)
# Out:
# S    72.502806
# C    18.855219
# Q     8.641975
# Name: Embarked, dtype: float64

# %% [markdown]
# ### outlier detection

# %%
sns.displot(x=train["Age"], kde=True,stat='density')
print(train["Age"].skew())
print(train["Age"].kurt())
# Out:
# 0.4344880940129925
# 0.9662793026645233

# %%
sns.boxplot(x=train["Age"])
print('_'*50)
print("people with  age in between 0 and 1 included are", train[(train['Age']<=1)].shape[0])
print("people who died between age 55 and 70 are",train[(train["Age"]>55) & (train["Age"]<70)].shape[0])
print("people who died between age 1 and 55 are",train[(train["Age"]>1) & (train["Age"]<55)].shape[0])
print("people with  age in between 70 and 75 are", train[(train['Age']>=70) & (train['Age']<=75)].shape[0])
print("people with  age above 75 are", train[(train['Age']>75)].shape[0])
print('_'*50)
# Out:
# __________________________________________________
# people with  age in between 0 and 1 included are 14
# people who died between age 55 and 70 are 33
# people who died between age 1 and 55 are 835
# people with  age in between 70 and 75 are 6
# people with  age above 75 are 1
# __________________________________________________

# %%
# outliers in fare column
sns.histplot(x=train["Fare"],kde=True,stat="density")
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
print("People with fare $100 or more are",train[(train["Fare"]>=100)].shape[0])
print("People with fare above $300 are",train[(train["Fare"]>300)].shape[0])
print("People with fare less than $20 are",train[(train["Fare"]<20)].shape[0])
# Out:
# People with fare $100 or more are 53
# People with fare above $300 are 3
# People with fare less than $20 are 515

# %% [markdown]
# ### Conclusion
# ##### 1. Highly skewed data , lots of people had cheaper tickets
# ##### 2. Outliers are there in the data

# %% [markdown]
# ## Multivariate Data Analysis

# %%
# Survival with Pclass

sns.countplot(x=train['Survived'],hue=train['Pclass'])
pd.crosstab(train['Pclass'],train['Survived']).apply(lambda r: round((r/r.sum())*100,1), axis=1)
# Out:
# Survived     0     1
# Pclass
# 1         37.0  63.0
# 2         52.7  47.3
# 3         75.8  24.2

# %%
# Survival with Sex

sns.countplot(x=train['Survived'],hue=train['Sex'])
pd.crosstab(train['Sex'],train['Survived']).apply(lambda r: round((r/r.sum())*100,1), axis=1)
# Out:
# Survived     0     1
# Sex
# female    25.8  74.2
# male      81.1  18.9

# %%
# Survival with Embarked

sns.countplot(x=train['Survived'],hue=train['Embarked'])
pd.crosstab(train['Embarked'],train['Survived']).apply(lambda r: round((r/r.sum())*100,1), axis=1)
# Out:
# Survived     0     1
# Embarked
# C         44.6  55.4
# Q         61.0  39.0
# S         66.1  33.9

# %%
#Survived with age
plt.figure(figsize=(11, 6))
sns.histplot(train[train['Survived'] == 0]['Age'], color='green', label='Not_Survived', kde=True)
sns.histplot(train[train['Survived'] == 1]['Age'], color='black', label='Survived', kde=True)
plt.legend()
plt.show()

# %%
#Survived with Fare
plt.figure(figsize=(11, 6))
sns.histplot(train[train['Survived'] == 0]['Fare'], color='orange', label='Not_Survived', kde=True)
sns.histplot(train[train['Survived'] == 1]['Fare'], color='blue', label='Survived', kde=True)
plt.legend()
plt.show()

# %%
sns.heatmap(train.corr(), annot=True)
# Out:
# C:\Users\shilajit\AppData\Local\Temp\ipykernel_15896\1534458401.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train.corr(), annot=True)
# <Axes: >

# %% [markdown]
# #### Conclusion
# ##### 1. Chance of female survival is higher then male survival.
#
# ##### 2. Travelling in Pclass 3 was deadliest.
#
# ##### 3. Somehow, people going to C survived more.
#
# ##### 4. People in the age range 20 to 40 had a higher chance of surviving.
